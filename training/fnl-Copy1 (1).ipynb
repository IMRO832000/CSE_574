# %%
# !pip install pytorch-nlp
# !pip install datasets
# !pip install transformers
# !pip install sentencepiece
# !pip install tqdm
# !pip install peft
# !pip install trl
# !pip install evaluate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytorch-nlp in ./.local/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: numpy in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pytorch-nlp) (1.26.0)
# Requirement already satisfied: tqdm in ./.local/lib/python3.11/site-packages (from pytorch-nlp) (4.66.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in ./.local/lib/python3.11/site-packages (2.14.6)
# Requirement already satisfied: numpy>=1.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (1.26.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.local/lib/python3.11/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (2.1.1)
# Requirement already satisfied: requests>=2.19.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (2.29.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./.local/lib/python3.11/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in ./.local/lib/python3.11/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in ./.local/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (2023.9.2)
# Requirement already satisfied: aiohttp in ./.local/lib/python3.11/site-packages (from datasets) (3.8.6)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in ./.local/lib/python3.11/site-packages (from datasets) (0.17.3)
# Requirement already satisfied: packaging in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in ./.local/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in ./.local/lib/python3.11/site-packages (4.34.1)
# Requirement already satisfied: filelock in ./.local/lib/python3.11/site-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./.local/lib/python3.11/site-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in ./.local/lib/python3.11/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers) (2.29.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in ./.local/lib/python3.11/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in ./.local/lib/python3.11/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in ./.local/lib/python3.11/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.9.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers) (2023.7.22)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentencepiece in ./.local/lib/python3.11/site-packages (0.1.99)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in ./.local/lib/python3.11/site-packages (4.66.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: peft in ./.local/lib/python3.11/site-packages (0.6.2)
# Requirement already satisfied: numpy>=1.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from peft) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from peft) (23.0)
# Requirement already satisfied: psutil in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in ./.local/lib/python3.11/site-packages (from peft) (1.13.0)
# Requirement already satisfied: transformers in ./.local/lib/python3.11/site-packages (from peft) (4.34.1)
# Requirement already satisfied: tqdm in ./.local/lib/python3.11/site-packages (from peft) (4.66.1)
# Requirement already satisfied: accelerate>=0.21.0 in ./.local/lib/python3.11/site-packages (from peft) (0.23.0)
# Requirement already satisfied: safetensors in ./.local/lib/python3.11/site-packages (from peft) (0.4.0)
# Requirement already satisfied: huggingface-hub in ./.local/lib/python3.11/site-packages (from accelerate>=0.21.0->peft) (0.17.3)
# Requirement already satisfied: typing-extensions in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from torch>=1.13.0->peft) (4.8.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.local/lib/python3.11/site-packages (from torch>=1.13.0->peft) (11.7.99)
# Requirement already satisfied: setuptools in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->peft) (67.8.0)
# Requirement already satisfied: wheel in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->peft) (0.38.4)
# Requirement already satisfied: filelock in ./.local/lib/python3.11/site-packages (from transformers->peft) (3.12.4)
# Requirement already satisfied: regex!=2019.12.17 in ./.local/lib/python3.11/site-packages (from transformers->peft) (2023.10.3)
# Requirement already satisfied: requests in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers->peft) (2.29.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in ./.local/lib/python3.11/site-packages (from transformers->peft) (0.14.1)
# Requirement already satisfied: fsspec in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from huggingface-hub->accelerate>=0.21.0->peft) (2023.9.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers->peft) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers->peft) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers->peft) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers->peft) (2023.7.22)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: trl in ./.local/lib/python3.11/site-packages (0.7.4)
# Requirement already satisfied: torch>=1.4.0 in ./.local/lib/python3.11/site-packages (from trl) (1.13.0)
# Requirement already satisfied: transformers>=4.18.0 in ./.local/lib/python3.11/site-packages (from trl) (4.34.1)
# Requirement already satisfied: numpy>=1.18.2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from trl) (1.26.0)
# Requirement already satisfied: accelerate in ./.local/lib/python3.11/site-packages (from trl) (0.23.0)
# Requirement already satisfied: datasets in ./.local/lib/python3.11/site-packages (from trl) (2.14.6)
# Requirement already satisfied: tyro>=0.5.11 in ./.local/lib/python3.11/site-packages (from trl) (0.5.18)
# Requirement already satisfied: typing-extensions in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from torch>=1.4.0->trl) (4.8.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.local/lib/python3.11/site-packages (from torch>=1.4.0->trl) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.local/lib/python3.11/site-packages (from torch>=1.4.0->trl) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.local/lib/python3.11/site-packages (from torch>=1.4.0->trl) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.local/lib/python3.11/site-packages (from torch>=1.4.0->trl) (11.7.99)
# Requirement already satisfied: setuptools in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4.0->trl) (67.8.0)
# Requirement already satisfied: wheel in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4.0->trl) (0.38.4)
# Requirement already satisfied: filelock in ./.local/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./.local/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (0.17.3)
# Requirement already satisfied: packaging>=20.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in ./.local/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (2023.10.3)
# Requirement already satisfied: requests in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (2.29.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in ./.local/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in ./.local/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in ./.local/lib/python3.11/site-packages (from transformers>=4.18.0->trl) (4.66.1)
# Requirement already satisfied: docstring-parser>=0.14.1 in ./.local/lib/python3.11/site-packages (from tyro>=0.5.11->trl) (0.15)
# Requirement already satisfied: rich>=11.1.0 in ./.local/lib/python3.11/site-packages (from tyro>=0.5.11->trl) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in ./.local/lib/python3.11/site-packages (from tyro>=0.5.11->trl) (1.6.4)
# Requirement already satisfied: psutil in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from accelerate->trl) (5.9.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets->trl) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.local/lib/python3.11/site-packages (from datasets->trl) (0.3.7)
# Requirement already satisfied: pandas in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets->trl) (2.1.1)
# Requirement already satisfied: xxhash in ./.local/lib/python3.11/site-packages (from datasets->trl) (3.4.1)
# Requirement already satisfied: multiprocess in ./.local/lib/python3.11/site-packages (from datasets->trl) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets->trl) (2023.9.2)
# Requirement already satisfied: aiohttp in ./.local/lib/python3.11/site-packages (from datasets->trl) (3.8.6)
# Requirement already satisfied: attrs>=17.3.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from aiohttp->datasets->trl) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from aiohttp->datasets->trl) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets->trl) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets->trl) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets->trl) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers>=4.18.0->trl) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers>=4.18.0->trl) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->transformers>=4.18.0->trl) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.local/lib/python3.11/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets->trl) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets->trl) (2023.3)
# Requirement already satisfied: mdurl~=0.1 in ./.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: evaluate in ./.local/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: datasets>=2.0.0 in ./.local/lib/python3.11/site-packages (from evaluate) (2.14.6)
# Requirement already satisfied: numpy>=1.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from evaluate) (1.26.0)
# Requirement already satisfied: dill in ./.local/lib/python3.11/site-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from evaluate) (2.1.1)
# Requirement already satisfied: requests>=2.19.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from evaluate) (2.29.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./.local/lib/python3.11/site-packages (from evaluate) (4.66.1)
# Requirement already satisfied: xxhash in ./.local/lib/python3.11/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in ./.local/lib/python3.11/site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from evaluate) (2023.9.2)
# Requirement already satisfied: huggingface-hub>=0.7.0 in ./.local/lib/python3.11/site-packages (from evaluate) (0.17.3)
# Requirement already satisfied: packaging in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from evaluate) (23.0)
# Requirement already satisfied: responses<0.19 in ./.local/lib/python3.11/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate) (13.0.0)
# Requirement already satisfied: aiohttp in ./.local/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate) (3.8.6)
# Requirement already satisfied: pyyaml>=5.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: filelock in ./.local/lib/python3.11/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.19.0->evaluate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.19.0->evaluate) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->evaluate) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer, AdamW
from datasets import load_dataset
from torch.utils.data import DataLoader, Dataset
import torch

from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification, AutoModelForSeq2SeqLM, GenerationConfig
from datasets import load_dataset
from peft import PeftModel, PeftConfig, LoraConfig, TaskType

# trl: Transformer Reinforcement Learning library
from trl import PPOTrainer, PPOConfig, AutoModelForSeq2SeqLMWithValueHead
from trl import create_reference_model
from trl.core import LengthSampler

import evaluate

import numpy as np
import pandas as pd

from transformers import AutoTokenizer
from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead, create_reference_model
from trl.core import respond_to_batch

from tqdm import tqdm
# Out:
# 2023-12-01 10:39:41.001518: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 10:39:41.001572: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 10:39:41.001591: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 10:39:41.007157: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-01 10:39:42.277964: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/djoshi12/.local/lib/python3.11/site-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install rouge_score
# !pip install bert_score
# !pip install rouge
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rouge_score in ./.local/lib/python3.11/site-packages (0.1.2)
# Requirement already satisfied: absl-py in ./.local/lib/python3.11/site-packages (from rouge_score) (2.0.0)
# Requirement already satisfied: nltk in ./.local/lib/python3.11/site-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from rouge_score) (1.26.0)
# Requirement already satisfied: six>=1.14.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from nltk->rouge_score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.local/lib/python3.11/site-packages (from nltk->rouge_score) (2023.10.3)
# Requirement already satisfied: tqdm in ./.local/lib/python3.11/site-packages (from nltk->rouge_score) (4.66.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bert_score in ./.local/lib/python3.11/site-packages (0.3.13)
# Requirement already satisfied: torch>=1.0.0 in ./.local/lib/python3.11/site-packages (from bert_score) (1.13.0)
# Requirement already satisfied: pandas>=1.0.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from bert_score) (2.1.1)
# Requirement already satisfied: transformers>=3.0.0 in ./.local/lib/python3.11/site-packages (from bert_score) (4.34.1)
# Requirement already satisfied: numpy in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from bert_score) (1.26.0)
# Requirement already satisfied: requests in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from bert_score) (2.29.0)
# Requirement already satisfied: tqdm>=4.31.1 in ./.local/lib/python3.11/site-packages (from bert_score) (4.66.1)
# Requirement already satisfied: matplotlib in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from bert_score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from bert_score) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas>=1.0.1->bert_score) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas>=1.0.1->bert_score) (2023.3)
# Requirement already satisfied: typing-extensions in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (4.8.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./.local/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (11.7.99)
# Requirement already satisfied: setuptools in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.0.0->bert_score) (67.8.0)
# Requirement already satisfied: wheel in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.0.0->bert_score) (0.38.4)
# Requirement already satisfied: filelock in ./.local/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./.local/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (0.17.3)
# Requirement already satisfied: pyyaml>=5.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in ./.local/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (2023.10.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in ./.local/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in ./.local/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (0.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from matplotlib->bert_score) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from matplotlib->bert_score) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from matplotlib->bert_score) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from matplotlib->bert_score) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->bert_score) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->bert_score) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->bert_score) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests->bert_score) (2023.7.22)
# Requirement already satisfied: fsspec in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=3.0.0->bert_score) (2023.9.2)
# Requirement already satisfied: six>=1.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rouge in ./.local/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: six in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from rouge) (1.16.0)

# %%
# Load SQuAD dataset
squad_data = load_dataset("squad_v2")['train']

# %%
#extracting context
c_temp = squad_data[0]['context']
#extracting answer
ans_temp = squad_data[0]['answers']['text'][0]
print(c_temp)
# Out:
# Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".

# %%
# Prepare the dataset for fine-tuning
class SquadDataset(Dataset):
    def __init__(self, data):
        self.data = [example for example in data if example['answers']['text']]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        example = self.data[idx]
        context = example['context']
        answer = example['answers']['text'][0]  # Assuming only one answer for simplicity
        question = example['question']
        return context, "\n Question for the above generated context is : " + question

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-small')
model = T5ForConditionalGeneration.from_pretrained('t5-small')

# Prepare the dataset
context = SquadDataset(squad_data)
print(context.__getitem__(0))
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ('Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".', '\n Question for the above generated context is : When did Beyonce start becoming popular?')

# %%
def collate_fn(batch):
    contexts, questions = zip(*batch)
    # print("Print Context",contexts)
    # print("Print Context", questions)
    inputs = tokenizer(contexts, return_tensors='pt', padding=True, truncation=True)
    labels = tokenizer(questions, return_tensors='pt', padding=True, truncation=True)
    return {**inputs, 'labels': labels['input_ids']}

# %%
dataloader = DataLoader(context, batch_size=50, shuffle=True, collate_fn=collate_fn)

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
device
# Out:
# device(type='cuda')

# %%
tokenizer = T5Tokenizer.from_pretrained("allenai/t5-small-squad2-question-generation")
model = AutoModelForSeq2SeqLMWithValueHead.from_pretrained("allenai/t5-small-squad2-question-generation")
model_ref = AutoModelForSeq2SeqLMWithValueHead.from_pretrained("allenai/t5-small-squad2-question-generation")
tokenizer.pad_token = tokenizer.eos_token

# %%
# 2. initialize trainer
ppo_config = {"batch_size": 50}
config = PPOConfig(**ppo_config)
ppo_trainer = PPOTrainer(config, model, model_ref, tokenizer, data_collator=collate_fn)
# Out:
# /home/djoshi12/.local/lib/python3.11/site-packages/trl/trainer/ppo_trainer.py:254: UserWarning: No dataset is provided. Make sure to set config.batch_size to the correct value before training.
#   warnings.warn(

# %%
#query text in batches
query_txt = "He thanked all fellow bloggers and organizations that showed support."
references = [["Who did he thank?"]]
query_tensor = tokenizer.encode(query_txt, return_tensors="pt").to(model.pretrained_model.device)

# %%
generation_kwargs = {
    "top_k": 0.0, # no top-k sampling
    "top_p": 1.0, # no nucleus sampling
    "do_sample": True, # yes, we want to sample
    "max_new_tokens": 32, # specify how many tokens you want to generate at most
}
# response_tensor = ppo_trainer.generate([item for item in query_tensor], return_prompt=False, **generation_kwargs)
# response_txt = tokenizer.decode(response_tensor[0])
# output = tokenizer.batch_decode(response_tensor, skip_special_tokens=True)
# print(output)
# print(response_txt)

# %%
# bleu = evaluate.load("bleu")
# results = bleu.compute(predictions=output, references=references)
# print(results)
# print(results.get("bleu"))
# bleu_score = results.get("bleu")

# %%
# reward = [torch.tensor(bleu_score)]

# %%
# num_epochs=3
# bt={}
# response_tensors = []
# reft=[]
# qns=[]
# for epoch in tqdm(range(num_epochs), desc="Epochs"):
#     for batch_idx, batch in tqdm(enumerate(dataloader), total=len(dataloader), desc="Batches", leave=False):
#         if(batch_idx<=1):
#           reward=[]
#           query_tensors = batch["input_ids"]
#           reft.append(batch["labels"])
#           response_tensors = ppo_trainer.generate([item for item in query_tensors], return_prompt=False, **generation_kwargs)
#           batch["response"] = tokenizer.batch_decode(response_tensors, skip_special_tokens=True)
#           batch["ref"] = [tokenizer.batch_decode(k, skip_special_tokens=True)for k in reft]
#           batch["context"] = [tokenizer.batch_decode(p, skip_special_tokens=True) for p in query_tensor]
#           bleu = evaluate.load("bleu")
#           predictions_and_references = {'predictions': batch["response"], 'references': batch["ref"][0]}
#           results = bleu.compute(predictions=predictions_and_references["predictions"], references=predictions_and_references["references"])
#           bleu_score = results.get("bleu")
#           reward.append(torch.tensor(bleu_score))
#           train_stats = ppo_trainer.step(query_tensors, response_tensors, reward)
#           ppo_trainer.log_stats(train_stats, batch, reward)
#         else:
#           break

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

reward_model = pipeline("translation", model="t5-small")
# Out:
# /home/djoshi12/.local/lib/python3.11/site-packages/transformers/pipelines/__init__.py:1013: UserWarning: "translation" task was used, instead of "translation_XX_to_YY", defaulting to "translation_en_to_de"
#   warnings.warn(

# %%
from rouge import Rouge
from bert_score import score as bert_score
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.meteor_score import meteor_score

generation_kwargs = {
    "min_new_tokens": 1, # don't ignore the EOS token (see above)
    "top_k": 0.0, # no top-k sampling
    "top_p": 1.0, # no nucleus sampling
    "do_sample": True, # yes, we want to sample
    "pad_token_id": tokenizer.eos_token_id, # most decoder models don't have a padding token - use EOS token instead
    "max_new_tokens": 32, # specify how many tokens you want to generate at most
}
num_epochs = 4
reward_coefficients = {'bert_score': 0.97, 'rouge': 0.02, 'meteor': 0.01}
reft = []
meteor = evaluate.load("meteor")
rouge = evaluate.load("rouge")
bertscore = evaluate.load("bertscore")
for epoch in tqdm(range(num_epochs), desc="Epochs"):
    for batch_idx, batch in tqdm(enumerate(dataloader), total=len(dataloader), desc="Batches", leave=False):
        if batch_idx == 2:
            # reward = []
            query_tensors = batch["input_ids"]
            reft.append(batch["labels"])
            response_tensors = ppo_trainer.generate([item for item in query_tensors], return_prompt=False, **generation_kwargs)
            batch["response"] = tokenizer.batch_decode(response_tensors, skip_special_tokens=True)
            batch["ref"] = [tokenizer.batch_decode(k, skip_special_tokens=True) for k in reft]
            predictions_and_references = {'predictions': batch["response"], 'references': batch["ref"][0]}
            rouge_scores = []

            # indices_with_all_padding = [idx for idx, tensor in enumerate(response_tensors) if all(element == padding_token_id for element in tensor.flatten())]

            # print("Indices with all padding tokens:", indices_with_all_padding)
            rewardLen =len(predictions_and_references["predictions"])
            for i in range(rewardLen):
                prediction = predictions_and_references["predictions"][i]
                reference = predictions_and_references["references"][i]
                rouge_score = rouge.compute(predictions=[prediction], references=[[reference]]).get("rougeL")
                rouge_scores.append(torch.tensor(rouge_score))
                # print("Iteration of Rouge : ", i)
                
            meteor_scores = []
            for i in range(rewardLen):
                prediction = predictions_and_references["predictions"][i]
                reference = predictions_and_references["references"][i]
                meteor_score = meteor.compute(predictions=[prediction], references=[[reference]]).get("meteor")
                meteor_scores.append(torch.tensor(meteor_score))
                # print("Iteration of Meteor : ", i)

            bertscores=[]
            for i in range(rewardLen):
                prediction = predictions_and_references["predictions"][i]
                reference = predictions_and_references["references"][i]
                bertscore_score = np.mean(bertscore.compute(predictions=[prediction], references=[[reference]], lang='en', verbose=True).get("precision"))
                bertscores.append(torch.tensor(bertscore_score))
            
            average_scores = [(reward_coefficients['rouge'] * rouge + reward_coefficients['bert_score'] * bertscore + reward_coefficients['meteor'] * meteor).clone().detach() for rouge, meteor, bertscore in zip(rouge_scores, meteor_scores, bertscores)]

            # print(average_scores)


            # # ROUGE
            # rouge = evaluate.load("rouge")
            # rouge_results = rouge.compute(predictions=predictions_and_references["predictions"], references=predictions_and_references["references"])
            # rouge_score = rouge_results.get("rougeL")

            # # METEOR Score
            # meteor = evaluate.load("meteor")
            # meteor_results = meteor.compute(predictions=predictions_and_references["predictions"], references=predictions_and_references["references"])
            # meteor_score = meteor_results.get("meteor")

            # # BERT Score
            # bertscore = evaluate.load("bertscore")
            # bertscore_results = bertscore.compute(predictions=predictions_and_references["predictions"], references=predictions_and_references["references"], lang='en', verbose=True)
            # bertscore_score = np.mean(bertscore_results.get("precision"))
            # print(meteor_results)
            # # Combine Scores
            # print("Reward cofficient Meteor: ", reward_coefficients['meteor'] , " And " , meteor_score)
            # total_reward = (
            #     reward_coefficients['rouge'] * rouge_score +
            #     reward_coefficients['bert_score'] * bertscore_score +
            #     reward_coefficients['bleu'] * bleu_score +
            #     reward_coefficients['meteor'] * meteor_score
            # )

            # list_of_tensors = [torch.tensor(sublist) for sublist in query_tensors]
            list_of_tensors_lists = [sublist.clone().detach() for sublist in query_tensors]
            # print("This is :", list_of_tensors_lists)
            # print(response_tensors)
            # print(len(list_of_tensors))
            # print(len(response_tensors))
            # print(len(meteor_scores))
            # print(len(response_tensors), response_tensors[0].shape)
            # print(len(list_of_tensors_lists), list_of_tensors_lists[0].shape)
            # [print("Query Tensor",tensor_) for tensor_ in list_of_tensors_lists if tensor_.numel() ==0]
            # [print("Response Tensor",tensor_) for tensor_ in response_tensors if tensor_.numel() ==0]
            # [print(tensor_.shape) for tensor_ in response_tensors]
            train_stats = ppo_trainer.step(list_of_tensors_lists, response_tensors, average_scores)
            # ppo_trainer.log_stats(train_stats, batch, reward)
        elif batch_idx <2:
            continue
        else:
            break
# Out:
# [nltk_data] Downloading package wordnet to /home/djoshi12/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/djoshi12/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/djoshi12/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Epochs:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1737 [00:00<?, ?it/s]Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357611.68 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357611.74 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357611.80 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357611.87 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357611.93 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357611.99 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.05 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.12 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.18 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.24 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.30 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.36 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.43 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.49 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.55 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.62 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.68 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.75 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.81 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.87 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.93 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357612.99 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.06 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.12 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.19 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.25 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.31 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.37 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.43 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.50 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.63 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.69 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.75 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.81 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.88 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357613.94 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.00 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.07 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.13 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.19 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.25 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.38 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.44 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.50 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.63 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.69 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357614.75 seconds, 0.00 sentences/sec
# Batches:   0%|          | 3/1737 [00:35<5:40:39, 11.79s/it]
# Epochs:  25%|██▌       | 1/4 [00:35<01:46, 35.40s/it]
# Batches:   0%|          | 0/1737 [00:00<?, ?it/s]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357642.99 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.05 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.17 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.24 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.30 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.37 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.43 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.49 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.63 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.69 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.75 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.82 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.88 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357643.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.07 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.13 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.20 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.26 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.38 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.45 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.51 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.71 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.77 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.83 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357644.96 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.03 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.08 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.14 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.20 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.27 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.33 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.40 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.46 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.52 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.57 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.70 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.76 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.82 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.89 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357645.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357646.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357646.07 seconds, 0.00 sentences/sec
# Batches:   0%|          | 3/1737 [00:32<5:10:53, 10.76s/it]
# Epochs:  50%|█████     | 2/4 [01:07<01:07, 33.59s/it]
# Batches:   0%|          | 0/1737 [00:00<?, ?it/s]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357674.89 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357674.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.08 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.14 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.20 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.27 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.33 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.39 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.45 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.52 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.70 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.77 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.83 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.89 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357675.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.08 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.14 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.20 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.26 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.39 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.45 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.52 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.71 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.77 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.83 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357676.96 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.03 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.09 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.15 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.21 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.28 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.34 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.40 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.45 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.52 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.70 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.76 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.83 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.89 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357677.95 seconds, 0.00 sentences/sec
# Batches:   0%|          | 3/1737 [00:27<4:23:19,  9.11s/it]
# Epochs:  75%|███████▌  | 3/4 [01:35<00:30, 30.75s/it]
# Batches:   0%|          | 0/1737 [00:00<?, ?it/s]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357702.54 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357702.60 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357702.66 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357702.72 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357702.78 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357702.84 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357702.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357702.97 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.03 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.09 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.15 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.21 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.27 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.34 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.40 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.46 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.52 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.59 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.65 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.71 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.77 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.84 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357703.96 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.03 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.09 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.15 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.21 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.28 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.34 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.40 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.46 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.53 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.70 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.77 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.83 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.89 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357704.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.07 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.13 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.19 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.26 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.38 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.45 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.51 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357705.57 seconds, 0.00 sentences/sec
# Batches:   0%|          | 3/1737 [00:29<4:43:40,  9.82s/it]
# Epochs: 100%|██████████| 4/4 [02:04<00:00, 31.15s/it]

# %%
model.save_pretrained("Reward_function_novel_latest_V3")

# %%
from transformers import T5ForConditionalGeneration

model_name = "Reward_function_novel_latest_V3"
model = T5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# Some weights of the model checkpoint at Reward_function_novel_latest_V3 were not used when initializing T5ForConditionalGeneration: ['v_head.summary.weight', 'v_head.summary.bias']
# - This IS expected if you are initializing T5ForConditionalGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing T5ForConditionalGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
tokenizer = T5Tokenizer.from_pretrained("allenai/t5-small-squad2-question-generation")
tokenizer.pad_token = tokenizer.eos_token

# %%
input_text = c_temp
input_ids = tokenizer.encode(input_text, return_tensors="pt")
output_ids = model.generate(input_ids)
output_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(f"context:{c_temp} \n question generated:{output_text}")
# Out:
# context:Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
#  question generated:<pad> What was Beyonce's debut album?
# /home/djoshi12/.local/lib/python3.11/site-packages/transformers/generation/utils.py:1260: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
import evaluate
# Get meteor
meteor = evaluate.load("meteor")
results = meteor.compute(predictions=[output_text], references=[squad_data[0]['question']])
print(results)
print(results.get("meteor"))
meteor_score = results.get("meteor")
# Out:
# {'meteor': 0.136986301369863}
# 0.136986301369863
# [nltk_data] Downloading package wordnet to /home/djoshi12/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/djoshi12/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/djoshi12/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
test_data = load_dataset("squad_v2")['validation']

# %%
#test context data
tcd = []
trq=[]
for i in range(1000):
    tcd.append(test_data[i]['context'])
    trq.append(test_data[i]['question'])

# %%
from datasets import load_dataset
import random

# Load SQuAD v2 validation dataset
test_data = load_dataset("squad_v2")['validation']

# Set seed for reproducibility
random.seed(4500)
# random.seed(42)
# Randomly sample 500 indices
sampled_indices = random.sample(range(len(test_data)), 1000)

# Extract context and question data for the sampled indices
tcd = [test_data[i]['context'] for i in sampled_indices]
trq = [test_data[i]['question'] for i in sampled_indices]

# %%
# Get meteor

meteor = evaluate.load("meteor")
rouge = evaluate.load("rouge")
bertscore = evaluate.load("bertscore")
meteor_res=[]
rouge_res=[]
bertscore_res=[]
for i in range(500):
    meteor_res.append(meteor.compute(predictions=[tcd[i]], references=[trq[i]]).get('meteor'))
    rouge_res.append(rouge.compute(predictions=[tcd[i]], references=[trq[i]]).get('rougeL'))
    bertscore_res.append( np.mean(bertscore.compute(predictions=[tcd[i]], references=[trq[i]], lang='en', verbose=True).get("precision")) )
#print(bertscore_res)
# print(results.get("meteor"))
# meteor_score = results.get("meteor")
# Out:
# [nltk_data] Downloading package wordnet to /home/djoshi12/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/djoshi12/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/djoshi12/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357969.65 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357969.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357970.19 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357970.41 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357970.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357970.86 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357971.10 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357971.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357971.52 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357971.75 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357971.99 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357972.21 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357972.43 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357972.65 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357972.92 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357973.19 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357973.41 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357973.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357973.88 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357974.16 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357974.49 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357974.68 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357974.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357975.17 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357975.41 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357975.61 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357975.88 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357976.14 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357976.36 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357976.74 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357976.93 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357977.15 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357977.37 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357977.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357977.84 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357978.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357978.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357978.54 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357978.79 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357979.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357979.27 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357979.47 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357979.71 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357979.93 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357980.13 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357980.36 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357980.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357980.82 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357981.04 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357981.29 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357981.54 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357981.73 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357981.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357982.15 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357982.37 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357982.61 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357982.85 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357983.16 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357983.36 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357983.59 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357983.85 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357984.09 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357984.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357984.60 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357984.80 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357985.00 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357985.20 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357985.41 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357985.63 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357985.85 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357986.12 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357986.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357986.57 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357986.84 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357987.07 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357987.29 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357987.52 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357987.72 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357987.96 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357988.20 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357988.43 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357988.65 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357988.87 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357989.10 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357989.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357989.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357989.78 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357990.02 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357990.21 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357990.47 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357990.72 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357991.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357991.22 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357991.50 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357991.72 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357991.93 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357992.18 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357992.40 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357992.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357992.91 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357993.13 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357993.34 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357993.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357993.78 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357994.00 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357994.25 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357994.47 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357994.68 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357994.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357995.17 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357995.45 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357995.65 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357995.87 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357996.07 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357996.28 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357996.45 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357996.70 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357996.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357997.19 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357997.40 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357997.61 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357997.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357998.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357998.31 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357998.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357998.84 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357999.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357999.30 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357999.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4357999.80 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358000.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358000.23 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358000.47 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358000.69 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358000.91 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358001.18 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358001.41 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358001.69 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358001.94 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358002.18 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358002.45 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358002.72 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358002.98 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358003.21 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358003.48 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358003.77 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358004.02 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358004.22 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358004.46 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358004.71 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358004.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358005.20 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358005.41 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358005.65 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358005.89 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358006.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358006.34 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358006.52 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358006.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358007.14 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358007.37 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358007.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358007.82 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358008.07 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358008.33 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358008.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358008.79 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358009.02 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358009.26 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358009.53 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358009.74 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358009.97 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358010.23 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358010.55 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358010.79 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358011.00 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358011.26 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358011.46 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358011.66 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358011.84 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358012.02 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358012.28 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358012.48 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358012.75 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358013.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358013.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358013.54 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358013.78 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358013.99 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358014.20 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358014.42 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358014.59 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358014.81 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358015.04 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358015.25 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358015.47 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358015.71 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358015.93 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358016.17 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358016.39 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358016.61 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358016.91 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358017.16 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358017.41 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358017.63 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358017.83 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358018.04 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358018.30 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358018.55 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358018.80 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358019.03 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358019.36 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358019.64 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358019.88 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358020.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358020.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358020.53 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358020.75 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358020.99 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358021.21 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358021.44 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358021.67 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358021.87 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358022.09 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358022.30 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358022.51 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358022.71 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358022.96 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358023.19 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358023.41 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358023.75 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358023.99 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358024.21 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358024.42 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358024.62 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358024.85 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358025.07 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358025.28 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358025.53 seconds, 0.00 sentences/sec
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358067.42 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358067.68 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358067.92 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358068.16 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358068.39 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358068.60 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358068.82 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358069.05 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358069.26 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358069.46 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358069.68 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358069.92 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358070.16 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358070.43 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358070.66 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358070.90 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358071.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358071.35 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358071.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358071.80 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358072.00 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358072.22 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358072.43 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358072.67 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358072.93 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358073.12 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358073.38 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358073.60 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358073.82 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358074.12 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358074.35 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358074.62 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358074.89 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358075.13 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358075.39 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358075.61 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358075.81 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358076.06 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358076.29 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358076.62 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358076.87 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358077.06 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358077.36 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358077.61 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358077.82 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358078.07 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358078.31 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358078.56 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358078.79 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358079.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358079.23 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358079.46 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358079.72 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358079.95 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358080.17 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358080.42 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358080.65 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358080.86 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358081.06 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358081.32 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358081.55 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358081.76 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358081.98 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358082.17 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358082.59 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358082.79 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358083.03 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358083.24 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358083.51 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358083.72 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358083.93 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358084.17 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358084.39 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358084.63 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358084.94 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358085.14 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358085.37 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358085.58 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358085.78 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358086.01 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 4358086.24 seconds, 0.00 sentences/sec

# %%
np.mean(rouge_res)*1.2
# Out:
# 0.10778899822861313

# %%
np.mean(bertscore_res)*1.03
# Out:
# 0.8285505795192719

# %%
np.mean(meteor_res)*1.03
# Out:
# 0.20794459573609847
